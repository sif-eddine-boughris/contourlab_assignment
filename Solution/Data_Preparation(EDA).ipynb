# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "Data/sampled_data.csv" 
df_INIT = pd.read_csv(file_path)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)
# ___

# %%
df_INIT.shape
# Out:
# (500, 50)

# %%
df_INIT.head()
# Out:
#                                          image_url_1             category  \
# 0  https://fotos.skm.be/article/489205/489205_02_...                shirt
# 1  https://fotos.skm.be/article/507927/507927_01_...              sweater
# 2  https://fotos.skm.be/article/505938/505938_01_...  trousers_and_chinos
# 3  https://fotos.skm.be/article/479883/479883_01_...                skirt
# 4  https://fotos.skm.be/article/483726/483726_01_...                dress
#
#       style                              colors  gender  \
# 0    casual          magenta; multicolor; white  female
# 1    casual          coral; magenta; multicolor  female
# 2  business                                gray  female
# 3  feminine              blue; multicolor; navy  female
# 4  feminine  emerald-green; multicolor; mustard  female
#
#                      pattern             occasion  accessory_type  \
# 0                     shapes  semi-formal; summer             NaN
# 1         chevron; harlequin               winter             NaN
# 2                houndstooth          semi-formal             NaN
# 3  stripes; vertical-stripes  casual; semi-formal             NaN
# 4                     floral               dating             NaN
#
#   more_attributes  bag_type  ...  shorts_type slippers-shoe_type  \
# 0         buttons       NaN  ...          NaN                NaN
# 1     embroidered       NaN  ...          NaN                NaN
# 2             NaN       NaN  ...          NaN                NaN
# 3             NaN       NaN  ...          NaN                NaN
# 4             NaN       NaN  ...          NaN                NaN
#
#   sneakers_type sportswear_type sweatshirt_type swimwear_type tank_type  \
# 0           NaN             NaN             NaN           NaN       NaN
# 1           NaN             NaN             NaN           NaN       NaN
# 2           NaN             NaN             NaN           NaN       NaN
# 3           NaN             NaN             NaN           NaN       NaN
# 4           NaN             NaN             NaN           NaN       NaN
#
#        bottoms_type         barcode    brand
# 0               NaN  48920502040101   ETERNA
# 1               NaN  50792701020101   Geisha
# 2  classic-trousers  50593801040101     TONI
# 3               NaN  47988301030101    Nümph
# 4               NaN  48372601080101  Verpass
#
# [5 rows x 50 columns]

# %%
df_INIT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   image_url_1                  500 non-null    object
#  1   category                     500 non-null    object
#  2   style                        494 non-null    object
#  3   colors                       478 non-null    object
#  4   gender                       495 non-null    object
#  5   pattern                      421 non-null    object
#  6   occasion                     494 non-null    object
#  7   accessory_type               0 non-null      float64
#  8   more_attributes              155 non-null    object
#  9   bag_type                     0 non-null      float64
#  10  belt_type                    0 non-null      float64
#  11  material                     203 non-null    object
#  12  tops_fit                     240 non-null    object
#  13  sleeve_type                  244 non-null    object
#  14  tops_length                  236 non-null    object
#  15  overclothes_closure          44 non-null     object
#  16  blazer_neckline_type         7 non-null      object
#  17  underarm_sleeve_length       21 non-null     object
#  18  neckline_type                247 non-null    object
#  19  sleeve_length                237 non-null    object
#  20  heels_width                  0 non-null      float64
#  21  heels_height                 1 non-null      object
#  22  boots-shoe_type              0 non-null      float64
#  23  shoe_material                0 non-null      float64
#  24  bracelet_type                0 non-null      float64
#  25  overclothes_neckline_type    36 non-null     object
#  26  overclothes_type             14 non-null     object
#  27  waist_type                   177 non-null    object
#  28  bottoms_length               117 non-null    object
#  29  skirt_type                   135 non-null    object
#  30  skirt_length                 135 non-null    object
#  31  bottoms_fit                  120 non-null    object
#  32  glasses_type                 0 non-null      float64
#  33  headwear_type                0 non-null      float64
#  34  jumpsuit_length              4 non-null      object
#  35  necklet_type                 0 non-null      float64
#  36  neckwear_type                0 non-null      float64
#  37  overclothes-sleeveless_type  5 non-null      object
#  38  poncho_type                  1 non-null      object
#  39  sandals-shoe_type            0 non-null      float64
#  40  shorts_type                  0 non-null      float64
#  41  slippers-shoe_type           1 non-null      object
#  42  sneakers_type                0 non-null      float64
#  43  sportswear_type              1 non-null      object
#  44  sweatshirt_type              5 non-null      object
#  45  swimwear_type                0 non-null      float64
#  46  tank_type                    10 non-null     object
#  47  bottoms_type                 92 non-null     object
#  48  barcode                      500 non-null    int64
#  49  brand                        500 non-null    object
# dtypes: float64(15), int64(1), object(34)
# memory usage: 195.4+ KB

# %%
def plot_multivalued_column(df, column_name, separator=";"):
    """
    Function to plot the distribution of a column that contains multiple attributes per row.

    Parameters:
    df (DataFrame): The dataset.
    column_name (str): The name of the column to visualize.
    separator (str): The separator used to split multiple attributes (default is "; ").
    """
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the dataset.")
        return

    # Drop NaN values, convert to string, and split attributes
    df_expanded = (
        df[column_name].dropna().astype(str)
        .str.split(separator)  # Split values into lists
        .explode()  # Expand into separate rows
        .str.strip()  # Remove leading/trailing spaces
    )
   
    # Get correct value counts
    attribute_counts = df_expanded.value_counts()

    # Plot the distribution
    plt.figure(figsize=(12, 6))
    sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")
    plt.title(f"Distribution of Attributes in {column_name}")
    plt.xlabel("Count")
    plt.ylabel("Attributes")
    plt.show()

# %%
plot_multivalued_column(df_INIT,"category")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %% [markdown]
# There is one attribute called No detection that is seems does not belong with the category need to be removed

# %%
df_INIT = df_INIT[df_INIT['category'] != 'no-detection']

# %%
plot_multivalued_column(df_INIT,"category")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %%
plot_multivalued_column(df_INIT,"style")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %%
plot_multivalued_column(df_INIT,"colors")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %% [markdown]
# As observed, the attribute "multicolor" indicates the presence of more than one color, but it's not necessary for our analysis and can be removed.

# %%
df_INIT["colors"] = df_INIT["colors"].astype(str).apply(lambda x: ";".join([color.strip() for color in x.split(";") if color.strip().lower() != "multicolor"]) if x != "nan" else x)

# %%
plot_multivalued_column(df_INIT,"colors")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %%
plot_multivalued_column(df_INIT,"gender")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %%
plot_multivalued_column(df_INIT,"pattern")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %%
plot_multivalued_column(df_INIT,"occasion")
# Out:
# C:\Users\Sifeddine\AppData\Local\Temp\ipykernel_17328\3083600982.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=attribute_counts.index, x=attribute_counts.values, palette="coolwarm")

# %% [markdown]
# Our dataset originally contains 500 rows and 50 columns. However, some columns have missing values. First, we will check for any duplicate values. Then, we will review the columns to identify if any attributes can be merged to eliminate missing values. For the remaining missing values, we will either:
#
# 1. Fill them using a logical approach or domain knowledge.
# 2. Remove the column if it is not important for our analysis.
# 3. Remove the row if it contains missing values that are not significant.

# %% [markdown]
# ## Removing duplicate
# ___

# %%
value_counts = df_INIT['barcode'].value_counts()
print(value_counts)
# Out:
# barcode
# 47988301030101    3
# 49836901040101    3
# 49564705020101    2
# 47755201050101    2
# 49975101020101    2
#                  ..
# 23302404020101    1
# 49194501030101    1
# 50062101040101    1
# 50782201050101    1
# 50593801040101    1
# Name: count, Length: 477, dtype: int64

# %%
duplicates = df_INIT[df_INIT.duplicated(subset=['barcode'], keep="first")]

print("Duplicate rows based on the specified column:")
print(duplicates)
# Out:
# Duplicate rows based on the specified column:
#                                            image_url_1             category  \
# 91   https://fotos.skm.be/article/503364/503364_01_...                skirt
# 147  https://fotos.skm.be/article/491749/491749_01_...                dress
# 157  https://fotos.skm.be/article/510218/510218_01_...               blouse
# 210  https://fotos.skm.be/article/479883/479883_01_...                skirt
# 215  https://fotos.skm.be/article/477552/477552_01_...                skirt
# 267  https://fotos.skm.be/article/497677/497677_01_...                dress
# 336  https://fotos.skm.be/article/484148/484148_01_...                skirt
# 347  https://fotos.skm.be/article/495647/495647_05_...  trousers_and_chinos
# 370  https://fotos.skm.be/article/487242/487242_01_...                skirt
# 373  https://fotos.skm.be/article/479883/479883_01_...                skirt
# 378  https://fotos.skm.be/article/492465/492465_01_...                skirt
# 388  https://fotos.skm.be/article/482842/482842_01_...                dress
# 389  https://fotos.skm.be/article/494602/494602_01_...  trousers_and_chinos
# 409  https://fotos.skm.be/article/478351/478351_01_...                skirt
# 445  https://fotos.skm.be/article/498369/498369_01_...                skirt
# 453  https://fotos.skm.be/article/498825/498825_01_...                skirt
# 493  https://fotos.skm.be/article/498369/498369_01_...                skirt
# 497  https://fotos.skm.be/article/499751/499751_01_...                shirt
#
#         style         colors  gender                    pattern  \
# 91   bohemian     orange;red    male                       leaf
# 147  feminine     black;gold  female                  geometric
# 157    casual  emerald-green    male                    glitter
# 210  feminine      blue;navy  female  stripes; vertical-stripes
# 215  feminine  emerald-green  female                        NaN
# 267  feminine      red;white  female                       leaf
# 336    casual   black;yellow  female                        NaN
# 347    casual        mustard  female                      plain
# 370  feminine      red;white  female               brush-stroke
# 373  feminine      blue;navy  female  stripes; vertical-stripes
# 378    casual     black;gray  female                       dots
# 388  feminine    ecru;yellow    male               floral; leaf
# 389    casual          black  female                      plain
# 409  feminine        mustard    male                      plain
# 445  feminine           blue  female                      plain
# 453  feminine         purple  female                      plain
# 493  feminine           blue  female                      plain
# 497    casual    beige;black  female                  geometric
#
#                                           occasion  accessory_type  \
# 91                           beach; dating; summer             NaN
# 147                                 casual; dating             NaN
# 157                                         casual             NaN
# 210                            casual; semi-formal             NaN
# 215  dating; nightout; semi-formal; summer; winter             NaN
# 267                                 casual; dating             NaN
# 336                                 dating; summer             NaN
# 347                  dating; nightout; semi-formal             NaN
# 370                            dating; semi-formal             NaN
# 373                            casual; semi-formal             NaN
# 378                            casual; home-lounge             NaN
# 388                                 casual; dating             NaN
# 389                            office; semi-formal             NaN
# 409                                 casual; dating             NaN
# 445                            casual; semi-formal             NaN
# 453                  dating; nightout; semi-formal             NaN
# 493                            casual; semi-formal             NaN
# 497                            semi-formal; summer             NaN
#
#     more_attributes  bag_type  ...  shorts_type slippers-shoe_type  \
# 91              NaN       NaN  ...          NaN                NaN
# 147         keyhole       NaN  ...          NaN                NaN
# 157             NaN       NaN  ...          NaN                NaN
# 210             NaN       NaN  ...          NaN                NaN
# 215         pleated       NaN  ...          NaN                NaN
# 267             NaN       NaN  ...          NaN                NaN
# 336             NaN       NaN  ...          NaN                NaN
# 347             NaN       NaN  ...          NaN                NaN
# 370             NaN       NaN  ...          NaN                NaN
# 373             NaN       NaN  ...          NaN                NaN
# 378             NaN       NaN  ...          NaN                NaN
# 388             NaN       NaN  ...          NaN                NaN
# 389         buttons       NaN  ...          NaN                NaN
# 409          ruched       NaN  ...          NaN                NaN
# 445             NaN       NaN  ...          NaN                NaN
# 453             NaN       NaN  ...          NaN                NaN
# 493             NaN       NaN  ...          NaN                NaN
# 497         buttons       NaN  ...          NaN                NaN
#
#     sneakers_type sportswear_type sweatshirt_type swimwear_type tank_type  \
# 91            NaN             NaN             NaN           NaN       NaN
# 147           NaN             NaN             NaN           NaN       NaN
# 157           NaN             NaN             NaN           NaN       NaN
# 210           NaN             NaN             NaN           NaN       NaN
# 215           NaN             NaN             NaN           NaN       NaN
# 267           NaN             NaN             NaN           NaN       NaN
# 336           NaN             NaN             NaN           NaN       NaN
# 347           NaN             NaN             NaN           NaN       NaN
# 370           NaN             NaN             NaN           NaN       NaN
# 373           NaN             NaN             NaN           NaN       NaN
# 378           NaN             NaN             NaN           NaN       NaN
# 388           NaN             NaN             NaN           NaN       NaN
# 389           NaN             NaN             NaN           NaN       NaN
# 409           NaN             NaN             NaN           NaN       NaN
# 445           NaN             NaN             NaN           NaN       NaN
# 453           NaN             NaN             NaN           NaN       NaN
# 493           NaN             NaN             NaN           NaN       NaN
# 497           NaN             NaN             NaN           NaN       NaN
#
#          bottoms_type         barcode                brand
# 91                NaN  50336401040101        Caroline Biss
# 147               NaN  49174901050101         Xandres Gold
# 157               NaN  51021801050101       Joseph Ribkoff
# 210               NaN  47988301030101                Nümph
# 215               NaN  47755201050101          GERRY WEBER
# 267               NaN  49767701050101  GERRY WEBER EDITION
# 336               NaN  48414801040101        Caroline Biss
# 347            chinos  49564705020101                 BRAX
# 370               NaN  48724201050101          GERRY WEBER
# 373               NaN  47988301030101                Nümph
# 378               NaN  49246501030101           King Louie
# 388               NaN  48284201020101        Second Female
# 389  classic-trousers  49460201030101        FAM the label
# 409               NaN  47835101030101           Julia June
# 445               NaN  49836901040101                Gigue
# 453               NaN  49882501040101           Julia June
# 493               NaN  49836901040101                Gigue
# 497               NaN  49975101020101                 ONLY
#
# [18 rows x 50 columns]

# %% [markdown]
# We can see that we have 477 Unique value and 18 duplicate

# %%
df_unique = df_INIT.drop_duplicates(subset=['barcode'])
df_unique.shape
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 0 to 499
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   image_url_1                  477 non-null    object
#  1   category                     477 non-null    object
#  2   style                        476 non-null    object
#  3   colors                       477 non-null    object
#  4   gender                       477 non-null    object
#  5   pattern                      405 non-null    object
#  6   occasion                     476 non-null    object
#  7   accessory_type               0 non-null      float64
#  8   more_attributes              150 non-null    object
#  9   bag_type                     0 non-null      float64
#  10  belt_type                    0 non-null      float64
#  11  material                     197 non-null    object
#  12  tops_fit                     238 non-null    object
#  13  sleeve_type                  239 non-null    object
#  14  tops_length                  234 non-null    object
#  15  overclothes_closure          44 non-null     object
#  16  blazer_neckline_type         7 non-null      object
#  17  underarm_sleeve_length       21 non-null     object
#  18  neckline_type                244 non-null    object
#  19  sleeve_length                232 non-null    object
#  20  heels_width                  0 non-null      float64
#  21  heels_height                 1 non-null      object
#  22  boots-shoe_type              0 non-null      float64
#  23  shoe_material                0 non-null      float64
#  24  bracelet_type                0 non-null      float64
#  25  overclothes_neckline_type    36 non-null     object
#  26  overclothes_type             14 non-null     object
#  27  waist_type                   164 non-null    object
#  28  bottoms_length               115 non-null    object
#  29  skirt_type                   121 non-null    object
#  30  skirt_length                 121 non-null    object
#  31  bottoms_fit                  118 non-null    object
#  32  glasses_type                 0 non-null      float64
#  33  headwear_type                0 non-null      float64
#  34  jumpsuit_length              4 non-null      object
#  35  necklet_type                 0 non-null      float64
#  36  neckwear_type                0 non-null      float64
#  37  overclothes-sleeveless_type  5 non-null      object
#  38  poncho_type                  1 non-null      object
#  39  sandals-shoe_type            0 non-null      float64
#  40  shorts_type                  0 non-null      float64
#  41  slippers-shoe_type           1 non-null      object
#  42  sneakers_type                0 non-null      float64
#  43  sportswear_type              1 non-null      object
#  44  sweatshirt_type              5 non-null      object
#  45  swimwear_type                0 non-null      float64
#  46  tank_type                    10 non-null     object
#  47  bottoms_type                 90 non-null     object
#  48  barcode                      477 non-null    int64
#  49  brand                        477 non-null    object
# dtypes: float64(15), int64(1), object(34)
# memory usage: 190.1+ KB

# %% [markdown]
# ### Steps to Handle Missing Values and Data Merging
#
# 1. **Merge Attributes**: Where applicable, combine multiple attributes from different columns to fill in missing values. This approach can help generate more comprehensive information from existing data.
#
# 2. **Handle Missing Values**:
#    - **Impute Missing Values**: Apply logical or domain-specific methods to impute or fill missing values. This could involve using statistical measures, such as the mean, median, or mode, or more advanced techniques based on the context of the data.
#    - **Drop Irrelevant Columns**: Identify and remove columns that are not essential for the analysis or that don't contribute meaningful information to the dataset.
#    - **Drop Irrelevant Rows**: Remove rows containing missing values that do not impact the overall dataset, especially if these rows are not crucial for your analysis or prediction objectives.
#
# ---

# %% [markdown]
# ## Merging Colomn
# ___

# %% [markdown]
# ### merging bottom_fit and top_fit into one colomn called "fit"
# We are combining the bottom_fit and top_fit columns into a new column called fit. To ensure consistency, we map the attributes from both columns into standardized fit categories.
#
# For the bottom_fit column, the various fit types, such as "straight-fit-bottoms" and "slim-bottoms", are grouped into broader categories like "Regular Fit", "Slim Fit", "Oversized Fit", and "Flared Fit".
#
# For the top_fit column, attributes like "regular-fit-tops" and "oversized-tops" are similarly mapped to fit categories like "Regular Fit", "Oversized Fit", and "Slim Fit".
#
# By applying these mappings, we can combine the two columns into one, creating a unified fit column that represents the overall fit for both tops and bottoms in the dataset.

# %%
df_merge_fit =df_unique.copy()

bottom_fit_mapping = {
    "straight-fit-bottoms": "Regular_Fit",
    "slim-bottoms": "Slim_Fit",
    "skinny-bottoms": "Slim_Fit",
    "oversized-bottoms": "Oversized_Fit",
    "wide-bottoms": "Oversized_Fit",
    "flare-bottoms": "Flared_Fit"
}

# Mapping for tops_fit
top_fit_mapping = {
    "regular-fit-tops": "Regular_Fit",
    "oversized-tops": "Oversized_Fit",
    "bodycon-tops": "Slim_Fit",
    "fitted-tops": "Slim_Fit"
}

# Apply mapping while keeping NaN values
df_merge_fit.loc[:, 'bottoms_fit'] = df_merge_fit['bottoms_fit'].map(bottom_fit_mapping)
df_merge_fit.loc[:, 'tops_fit'] = df_merge_fit['tops_fit'].map(top_fit_mapping)

# Function to combine both fits
def combine_fits(row):
    top = row['tops_fit']
    bottom = row['bottoms_fit']
    
    if pd.isna(top) and pd.isna(bottom):
        return None  # Keep NaN if both are missing
    elif pd.isna(top):
        return bottom  # Keep bottom if top is missing
    elif pd.isna(bottom):
        return top  # Keep top if bottom is missing
    elif top == bottom:
        return top  # Keep only one if both are the same
    else:
        return f"{top}; {bottom}"  # Combine both with "; "


# Apply function to create 'fit' column
df_merge_fit.loc[:, 'fit'] = df_merge_fit.apply(combine_fits, axis=1)
df_merge_fit = df_merge_fit.drop(columns=['tops_fit', 'bottoms_fit'])
# Print unique values with counts
print(df_merge_fit['fit'].value_counts(dropna=False))

df_merge_fit.info()
# Out:
# fit
# Regular_Fit                   188
# None                          125
# Oversized_Fit                  82
# Slim_Fit                       73
# Flared_Fit                      7
# Oversized_Fit; Slim_Fit         1
# Regular_Fit; Oversized_Fit      1
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 0 to 499
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   image_url_1                  477 non-null    object
#  1   category                     477 non-null    object
#  2   style                        476 non-null    object
#  3   colors                       477 non-null    object
#  4   gender                       477 non-null    object
#  5   pattern                      405 non-null    object
#  6   occasion                     476 non-null    object
#  7   accessory_type               0 non-null      float64
#  8   more_attributes              150 non-null    object
#  9   bag_type                     0 non-null      float64
#  10  belt_type                    0 non-null      float64
#  11  material                     197 non-null    object
#  12  sleeve_type                  239 non-null    object
#  13  tops_length                  234 non-null    object
#  14  overclothes_closure          44 non-null     object
#  15  blazer_neckline_type         7 non-null      object
#  16  underarm_sleeve_length       21 non-null     object
#  17  neckline_type                244 non-null    object
#  18  sleeve_length                232 non-null    object
#  19  heels_width                  0 non-null      float64
#  20  heels_height                 1 non-null      object
#  21  boots-shoe_type              0 non-null      float64
#  22  shoe_material                0 non-null      float64
#  23  bracelet_type                0 non-null      float64
#  24  overclothes_neckline_type    36 non-null     object
#  25  overclothes_type             14 non-null     object
#  26  waist_type                   164 non-null    object
#  27  bottoms_length               115 non-null    object
#  28  skirt_type                   121 non-null    object
#  29  skirt_length                 121 non-null    object
#  30  glasses_type                 0 non-null      float64
#  31  headwear_type                0 non-null      float64
#  32  jumpsuit_length              4 non-null      object
#  33  necklet_type                 0 non-null      float64
#  34  neckwear_type                0 non-null      float64
#  35  overclothes-sleeveless_type  5 non-null      object
#  36  poncho_type                  1 non-null      object
#  37  sandals-shoe_type            0 non-null      float64
#  38  shorts_type                  0 non-null      float64
#  39  slippers-shoe_type           1 non-null      object
#  40  sneakers_type                0 non-null      float64
#  41  sportswear_type              1 non-null      object
#  42  sweatshirt_type              5 non-null      object
#  43  swimwear_type                0 non-null      float64
#  44  tank_type                    10 non-null     object
#  45  bottoms_type                 90 non-null     object
#  46  barcode                      477 non-null    int64
#  47  brand                        477 non-null    object
#  48  fit                          352 non-null    object
# dtypes: float64(15), int64(1), object(33)
# memory usage: 186.3+ KB

# %% [markdown]
# ### Merging Columns Containing the Type Attribute into One Column
# The goal is to consolidate several columns that represent different types of attributes into one unified column. These columns typically contain various categories or classifications of clothing types such as sleeve types, neckline types, and so on. We aim to merge these columns into a single column, providing a more streamlined representation of the data.

# %%
type_columns = [col for col in df_merge_fit.columns if 'type' in col.lower()]

# Print the columns that contain "type"
print(type_columns)
# Out:
# ['accessory_type', 'bag_type', 'belt_type', 'sleeve_type', 'blazer_neckline_type', 'neckline_type', 'boots-shoe_type', 'bracelet_type', 'overclothes_neckline_type', 'overclothes_type', 'waist_type', 'skirt_type', 'glasses_type', 'headwear_type', 'necklet_type', 'neckwear_type', 'overclothes-sleeveless_type', 'poncho_type', 'sandals-shoe_type', 'shorts_type', 'slippers-shoe_type', 'sneakers_type', 'sportswear_type', 'sweatshirt_type', 'swimwear_type', 'tank_type', 'bottoms_type']

# %%
df_merge_Type =df_merge_fit.copy()
# Combine values of the selected columns into one column 'Type'
df_merge_Type['Type'] = df_merge_Type[type_columns].apply(lambda row: ' '.join(row.fillna('').astype(str)), axis=1)
df_merge_Type['Type'] = df_merge_Type['Type'].apply(lambda x: ';'.join(str(val) for val in x.split() if val) if x.strip() != '' else None
)

df_merge_Type.drop(columns=type_columns, inplace=True)
print(df_merge_Type['Type'])
# Out:
# 0             straight-sleeve;high-neck
# 1           straight-sleeve;turtle-neck
# 2           high-waist;classic-trousers
# 3                     high-waist;a-line
# 4         straight-sleeve;v-neck;pencil
#                      ...
# 494         high-waist;classic-trousers
# 495      straight-sleeve;notched-collar
# 496    straight-sleeve;boat-neck;pencil
# 498              straight-sleeve;v-neck
# 499                     straight-sleeve
# Name: Type, Length: 477, dtype: object

# %%
for value in df_merge_Type['Type']:
    print(value)
# Out:
# straight-sleeve;high-neck
# straight-sleeve;turtle-neck
# high-waist;classic-trousers
# high-waist;a-line
# straight-sleeve;v-neck;pencil
# straight-sleeve;crew-neck
# straight-sleeve
# puff-sleeve;boat-neck
# straight-sleeve;v-neck
# mid-waist;classic-trousers
# straight-sleeve;grandad
# crew-neck
# straight-sleeve;boat-neck
# straight-sleeve;v-neck
# crew-neck
# flutter-sleeve;shoulder-off;pencil
# straight-sleeve;v-neck;a-line
# high-waist
# high-waist;casual
# puff-sleeve;polo;a-line
# high-waist;a-line
# puff-sleeve;v-neck
# straight-sleeve;v-neck;a-line
# v-neck;a-line
# high-waist;classic-trousers
# straight-sleeve;v-neck;a-line
# straight-sleeve;high-neck
# straight-sleeve;crew-neck
# mid-waist;classic-trousers
# high-waist;a-line
# round-neck;sleeveless
# high-waist;a-line
# straight-sleeve;high-neck;everyday-overclothes
# round-neck
# straight-sleeve;v-neck;a-line
# straight-sleeve;v-neck;a-line
# mid-waist;classic-trousers
# straight-sleeve;cutaway;denim-overclothes
# mid-waist;classic-trousers
# crew-neck
# high-waist;chinos
# boat-neck
# boat-neck
# straight-sleeve;v-neck;pencil
# straight-sleeve
# high-waist;a-line
# round-neck;sleeveless
# mid-waist;classic-trousers
# straight-sleeve;round-neck;a-line
# crew-neck
# high-waist;a-line
# high-waist
# straight-sleeve;polo
# mid-waist;classic-trousers
# crew-neck
# high-waist;classic-trousers
# straight-sleeve
# straight-sleeve;v-neck;a-line
# mid-waist;classic-trousers
# v-neck
# straight-sleeve;v-neck;bodycon
# straight-sleeve;cutaway;leather-overclothes
# straight-sleeve;round-neck
# mid-waist;classic-trousers
# flutter-sleeve;crew-neck
# straight-sleeve;crew-neck
# mid-waist;classic-trousers
# flutter-sleeve;v-neck;a-line
# high-waist;a-line
# high-waist;pencil
# mid-waist
# straight-sleeve;pencil
# puff-sleeve;round-neck;a-line
# dolman-sleeve;boat-neck
# puff-sleeve;v-neck;mermaid
# straight-sleeve;notched-collar
# crew-neck
# high-waist;a-line
# straight-sleeve;boat-neck
# sweetheart-neck;straps
# flare-sleeve
# dolman-sleeve;v-neck
# straight-sleeve;polo
# mid-waist;classic-trousers
# high-waist;classic-trousers
# dolman-sleeve;boat-neck
# straight-sleeve;v-neck;a-line
# high-waist;classic-trousers
# square-neck
# straight-sleeve;polo;leather-overclothes
# clogs_and_mules
# straight-sleeve;crew-neck
# high-waist;classic-trousers
# v-neck
# vests
# high-waist;classic-trousers
# crew-neck;sleeveless
# straight-sleeve;v-neck
# straight-sleeve
# straight-sleeve
# hooded;vests
# puff-sleeve;round-neck;a-line
# v-neck;waistcoat
# high-waist;a-line
# mid-waist;classic-trousers
# high-waist;classic-trousers
# mid-waist;classic-trousers
# straight-sleeve;round-v-neck
# high-waist;a-line
# straight-sleeve;round-neck
# round-neck
# flutter-sleeve;v-neck
# high-waist
# v-neck;a-line
# mid-waist
# straight-sleeve;turtle-neck
# mid-waist
# straight-sleeve;hooded;puffer
# high-waist;classic-trousers
# straight-sleeve
# v-neck
# straight-sleeve;crew-neck
# v-neck;a-line
# straight-sleeve;hooded;trenchcoat
# high-waist;a-line
# dolman-sleeve;boat-neck
# straight-sleeve;v-neck;a-line
# high-waist;chinos
# straight-sleeve;crew-neck
# straight-sleeve;round-neck;bodycon
# high-waist;a-line
# straight-sleeve;v-neck;a-line
# straight-sleeve;high-neck
# round-neck
# crew-neck
# straight-sleeve;v-neck;a-line
# straight-sleeve;high-neck
# puff-sleeve;turtle-neck
# round-v-neck;a-line
# straight-sleeve;boat-neck;everyday-sweatshirt
# high-waist;classic-trousers
# straight-sleeve;v-neck;a-line
# dolman-sleeve;cutaway
# puff-sleeve;v-neck
# high-waist;classic-trousers
# straight-sleeve;turtle-neck
# straight-sleeve;crew-neck
# high-waist
# high-waist;pencil
# v-neck
# puff-sleeve
# straight-sleeve
# straight-sleeve;crew-neck
# mid-waist;classic-trousers
# straight-sleeve;hooded;everyday-overclothes
# straight-sleeve;v-neck;a-line
# v-neck
# high-waist;classic-trousers
# dolman-sleeve;round-neck
# mid-waist
# high-waist;classic-trousers
# straight-sleeve;high-neck;everyday-sweatshirt
# mid-waist
# straight-sleeve;polo
# high-waist;a-line
# high-waist
# high-waist;a-line
# mid-waist;classic-trousers
# high-neck;pencil
# straight-sleeve;v-neck
# straight-sleeve;round-neck
# mid-waist;a-line
# high-waist;a-line
# straight-sleeve;notched-collar
# straight-sleeve;v-neck;a-line
# straight-sleeve;high-neck;a-line
# high-waist;classic-trousers
# high-waist;a-line
# straight-sleeve;crew-neck
# straight-sleeve;v-neck;a-line
# straight-sleeve;v-neck
# high-waist;classic-trousers
# puff-sleeve;v-neck
# straight-sleeve;notched-collar
# puff-sleeve;high-neck
# high-waist;a-line
# straight-sleeve;round-v-neck
# boat-neck
# high-waist;classic-trousers
# high-waist;a-line
# puff-sleeve;boat-neck
# high-waist;classic-trousers
# high-neck;cape
# straight-sleeve;polo
# high-waist;classic-trousers
# mid-waist;pencil
# one-shoulder
# high-waist;classic-trousers
# round-neck;sleeveless
# mid-waist;classic-trousers
# v-neck;a-line
# mid-waist;classic-trousers
# straight-sleeve;polo;denim-overclothes
# high-waist;classic-trousers
# crew-neck
# crew-neck
# straight-sleeve;round-v-neck
# straight-sleeve;round-neck
# mid-waist;chinos
# straight-sleeve;v-neck;a-line
# mid-waist
# mid-waist
# straight-sleeve;high-neck
# crew-neck;sleeveless
# mid-waist
# mid-waist;pencil
# mid-waist;chinos
# straight-sleeve;v-neck;a-line
# straight-sleeve;crew-neck
# high-waist;classic-trousers
# straight-sleeve;v-neck
# high-waist;classic-trousers
# high-waist;classic-trousers
# mid-waist;chinos
# straight-sleeve;notched-collar
# high-waist;classic-trousers
# crew-neck
# high-waist
# straight-sleeve;crew-neck
# straight-sleeve;v-neck
# high-waist;a-line
# high-waist;classic-trousers
# straight-sleeve;crew-neck
# straight-sleeve;notched-collar
# mid-waist;classic-trousers
# mid-waist;classic-trousers
# straight-sleeve
# dolman-sleeve;v-neck
# high-waist;classic-trousers
# mid-waist;pencil
# mid-waist;classic-trousers
# straight-sleeve;round-neck
# mid-waist;classic-trousers
# straight-sleeve
# straight-sleeve;crew-neck
# high-waist;a-line
# straight-sleeve;v-neck;a-line
# mid-waist;a-line
# straight-sleeve;round-v-neck
# round-neck;sleeveless
# puff-sleeve;polo
# high-waist;a-line
# crew-neck
# v-neck
# mid-waist
# high-waist;classic-trousers
# straight-sleeve;cutaway;blend-coat
# crew-neck
# straight-sleeve;round-v-neck
# high-waist;a-line
# straight-sleeve;v-neck
# dolman-sleeve;round-neck;a-line
# high-waist;a-line
# high-waist;a-line
# straight-sleeve;round-neck;a-line
# dolman-sleeve;v-neck
# straight-sleeve;v-neck
# straight-sleeve;crew-neck
# high-waist;a-line
# straight-sleeve;high-neck
# round-neck
# high-waist;classic-trousers
# puff-sleeve;shawl-collar;blend-coat
# straight-sleeve
# straight-sleeve;round-v-neck;a-line
# straight-sleeve;v-neck;pencil
# straight-sleeve;round-v-neck
# dolman-sleeve;high-neck
# straight-sleeve;hooded;puffer
# straight-sleeve;round-v-neck;a-line
# round-neck
# straight-sleeve;polo
# boat-neck;bodycon
# high-waist;a-line
# high-waist;a-line
# straight-sleeve;hooded;everyday-overclothes
# high-waist;a-line
# low-waist
# straight-sleeve;high-neck
# high-waist;sport-shorts
# dolman-sleeve;round-v-neck
# straight-sleeve;shawl-collar;everyday-sweatshirt
# puff-sleeve;round-neck;a-line
# mid-waist;classic-trousers
# straight-sleeve;v-neck;a-line
# straight-sleeve;turtle-neck
# high-waist;classic-trousers
# dolman-sleeve;high-neck
# straight-sleeve;everyday-sweatshirt
# high-waist;classic-trousers
# mid-waist;classic-trousers
# straight-sleeve;v-neck
# polo;pencil
# high-waist;classic-trousers
# high-neck;vests
# straight-sleeve;round-neck
# mid-waist;pencil
# crew-neck
# straight-sleeve;crew-neck
# straight-sleeve
# straight-sleeve;crew-neck
# straight-sleeve;round-v-neck;pencil
# straight-sleeve
# dolman-sleeve;v-neck
# straight-sleeve;crew-neck
# straight-sleeve
# flutter-sleeve;v-neck
# straight-sleeve;v-neck;a-line
# mid-waist;pencil
# high-waist;classic-trousers
# dolman-sleeve;boat-neck
# straight-sleeve;round-v-neck
# high-waist
# round-neck
# straight-sleeve;high-neck
# flare-sleeve
# mid-waist;classic-trousers
# boat-neck
# straight-sleeve;cutaway
# puff-sleeve;v-neck
# straight-sleeve;cutaway
# mid-waist;classic-trousers
# straight-sleeve;boat-neck
# straight-sleeve
# round-neck;sleeveless
# high-waist;casual
# straight-sleeve;high-neck
# boat-neck
# high-waist;chinos
# straight-sleeve;v-neck;a-line
# high-waist;a-line
# high-waist;classic-trousers
# hooded;vests
# straight-sleeve;high-neck
# high-waist;classic-trousers
# straight-sleeve;hooded
# v-neck
# high-waist;a-line
# mid-waist;classic-trousers
# straight-sleeve;polo
# high-waist;a-line
# high-waist;a-line
# v-neck
# mid-waist
# mid-waist;classic-trousers
# straight-sleeve;crew-neck
# straight-sleeve;crew-neck;everyday-sweatshirt
# straight-sleeve;v-neck;a-line
# dolman-sleeve;round-neck
# high-waist;a-line
# straight-sleeve;high-neck
# high-waist
# straight-sleeve;high-neck
# v-neck
# crew-neck
# round-v-neck
# straight-sleeve;shawl-collar
# straight-sleeve;v-neck;pencil
# mid-waist;classic-trousers
# puff-sleeve;v-neck;a-line
# high-waist;a-line
# straight-sleeve;notched-collar
# round-neck;sleeveless
# dolman-sleeve;v-neck
# crew-neck
# high-waist;classic-trousers
# straight-sleeve;shawl-collar
# crew-neck
# mid-waist;classic-trousers
# high-waist;a-line
# straight-sleeve;round-neck
# high-waist;a-line
# straight-sleeve;v-neck
# mid-waist
# straight-sleeve;turtle-neck
# dolman-sleeve
# straight-sleeve;v-neck
# flutter-sleeve;round-neck
# high-waist;classic-trousers
# v-neck
# boat-neck
# straight-sleeve;v-neck;a-line
# low-waist;classic-trousers
# high-waist;classic-trousers
# straight-sleeve;round-neck
# high-waist;a-line
# straight-sleeve;v-neck
# straight-sleeve;v-neck
# straight-sleeve;v-neck
# straight-sleeve;round-neck
# high-waist;chinos
# straight-sleeve;high-neck;a-line
# high-waist;chinos
# mid-waist;classic-trousers
# high-waist;a-line
# straight-sleeve;boat-neck
# high-waist;classic-trousers
# round-neck
# mid-waist
# cutaway
# puff-sleeve;round-neck
# mid-waist;classic-trousers
# straight-sleeve;crew-neck
# puff-sleeve;crew-neck
# straight-sleeve;crew-neck
# flare-sleeve;v-neck
# round-neck
# v-neck;a-line
# v-neck;sleeveless
# dolman-sleeve;round-neck;pencil
# low-waist;classic-trousers
# v-neck;a-line
# straight-sleeve;round-neck
# straight-sleeve;v-neck;a-line
# straight-sleeve;crew-neck
# straight-sleeve;cutaway
# straight-sleeve;polo
# high-waist;a-line
# v-neck;pencil
# mid-waist
# high-waist;chinos
# boat-neck
# high-waist;classic-trousers
# straight-sleeve;v-neck;a-line
# high-waist;classic-trousers
# mid-waist
# straight-sleeve;polo;everyday-overclothes
# straight-sleeve;v-neck;a-line
# high-waist;classic-trousers
# straight-sleeve
# straight-sleeve;v-neck;a-line
# straight-sleeve;polo;denim-overclothes
# puff-sleeve;round-v-neck
# straight-sleeve;v-neck
# puff-sleeve;polo
# flare-sleeve;round-neck;a-line
# straight-sleeve;v-neck;a-line
# straight-sleeve
# straight-sleeve;v-neck;a-line
# mid-waist;classic-trousers
# puff-sleeve;a-line
# mid-waist;classic-trousers
# straight-sleeve;boat-neck
# straight-sleeve;v-neck;a-line
# straight-sleeve;high-neck
# flutter-sleeve;high-neck;a-line
# high-waist;classic-trousers
# flutter-sleeve;round-neck;a-line
# straight-sleeve;v-neck
# mid-waist
# puff-sleeve;v-neck;mermaid
# high-waist;classic-trousers
# straight-sleeve;round-v-neck
# crew-neck
# straight-sleeve;square-neck
# straight-sleeve;v-neck;a-line
# straight-sleeve;round-neck
# mid-waist
# straight-sleeve;v-neck;a-line
# high-waist;classic-trousers
# flutter-sleeve;round-v-neck;pencil
# straight-sleeve;crew-neck
# high-waist;classic-trousers
# straight-sleeve;notched-collar
# straight-sleeve;boat-neck;pencil
# straight-sleeve;v-neck
# straight-sleeve

# %%
df_merge_Type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 0 to 499
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   image_url_1             477 non-null    object
#  1   category                477 non-null    object
#  2   style                   476 non-null    object
#  3   colors                  477 non-null    object
#  4   gender                  477 non-null    object
#  5   pattern                 405 non-null    object
#  6   occasion                476 non-null    object
#  7   more_attributes         150 non-null    object
#  8   material                197 non-null    object
#  9   tops_length             234 non-null    object
#  10  overclothes_closure     44 non-null     object
#  11  underarm_sleeve_length  21 non-null     object
#  12  sleeve_length           232 non-null    object
#  13  heels_width             0 non-null      float64
#  14  heels_height            1 non-null      object
#  15  shoe_material           0 non-null      float64
#  16  bottoms_length          115 non-null    object
#  17  skirt_length            121 non-null    object
#  18  jumpsuit_length         4 non-null      object
#  19  barcode                 477 non-null    int64
#  20  brand                   477 non-null    object
#  21  fit                     352 non-null    object
#  22  Type                    477 non-null    object
# dtypes: float64(2), int64(1), object(20)
# memory usage: 89.4+ KB

# %% [markdown]
# ### Merging Length-Related Columns into a Single Column
# We will merge multiple columns representing different length attributes into one unified column. These columns usually contain various categories or classifications related to clothing length.

# %%
length_columns = [col for col in df_merge_Type.columns if 'length' in col.lower()]

# Print the columns that contain "length"
print(length_columns)
# Out:
# ['tops_length', 'underarm_sleeve_length', 'sleeve_length', 'bottoms_length', 'skirt_length', 'jumpsuit_length']

# %%
df_merge_lenghth =df_merge_Type.copy()
# Combine values of the selected columns into one column 'Type'
df_merge_lenghth['lenghth'] = df_merge_lenghth[length_columns].apply(lambda row: ' '.join(row.fillna('').astype(str)), axis=1)
df_merge_lenghth['lenghth'] = df_merge_lenghth['lenghth'].apply(lambda x: ';'.join(str(val) for val in x.split() if val) if x.strip() != '' else None
)

df_merge_lenghth.drop(columns=length_columns, inplace=True)
print(df_merge_lenghth['lenghth'])
# Out:
# 0             short;long-sleeve
# 1             short;long-sleeve
# 2                   full-length
# 3                          midi
# 4               3-4-sleeve;midi
#                  ...
# 494                    3-4-long
# 495    thigh-length;long-sleeve
# 496             3-4-sleeve;mini
# 498           short;long-sleeve
# 499           short;long-sleeve
# Name: lenghth, Length: 477, dtype: object

# %%
df_merge_lenghth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   image_url_1          477 non-null    object
#  1   category             477 non-null    object
#  2   style                476 non-null    object
#  3   colors               477 non-null    object
#  4   gender               477 non-null    object
#  5   pattern              405 non-null    object
#  6   occasion             476 non-null    object
#  7   more_attributes      150 non-null    object
#  8   material             197 non-null    object
#  9   overclothes_closure  44 non-null     object
#  10  heels_width          0 non-null      float64
#  11  heels_height         1 non-null      object
#  12  shoe_material        0 non-null      float64
#  13  barcode              477 non-null    int64
#  14  brand                477 non-null    object
#  15  fit                  352 non-null    object
#  16  Type                 477 non-null    object
#  17  lenghth              475 non-null    object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 70.8+ KB

# %% [markdown]
# now we can see that we have 18 column

# %% [markdown]
# ### Drop Irrelevant Columns
# ___

# %% [markdown]
# For the columns more_attributes, material, overclothes_closure, heels_width, heels_height, and shoe_material, which contain a significant amount of missing values, we have decided not to include them in our analysis. Therefore, we will remove these columns from the dataset.

# %%
df_filtered =df_merge_lenghth.copy()
columns_to_remove = ['more_attributes', 'material', 'overclothes_closure', 
                     'heels_width', 'heels_height', 'shoe_material']

# Remove these columns from the DataFrame
df_filtered.drop(columns=columns_to_remove, inplace=True)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image_url_1  477 non-null    object
#  1   category     477 non-null    object
#  2   style        476 non-null    object
#  3   colors       477 non-null    object
#  4   gender       477 non-null    object
#  5   pattern      405 non-null    object
#  6   occasion     476 non-null    object
#  7   barcode      477 non-null    int64
#  8   brand        477 non-null    object
#  9   fit          352 non-null    object
#  10  Type         477 non-null    object
#  11  lenghth      475 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 48.4+ KB

# %% [markdown]
# In our analysis, we identified several columns with missing values, specifically style, colors, occasion, pattern, gender, fit, Type, and length. To address this, we propose the following approaches:
#
# 1. Imputation of Missing Values: For categorical columns like style, occasion, gender, Type, and length, we plan to impute missing values using the mode (most frequent value) of each column. This will ensure consistency in the data while maintaining its integrity. For columns like pattern and fit, which contain critical information for analysis, we will either impute missing values using the mode or replace them with a default value, such as "Unknown" or "Other," based on domain-specific knowledge.
#
# 2. Handling Rows with Missing Values: If rows contain critical missing information (e.g., missing category), they may be removed entirely, as they would not contribute meaningfully to the analysis. For less critical columns, we will use logical imputation to retain the rows while maintaining data quality.
# ____

# %% [markdown]
# We will review the attributes of each column in the dataset to identify any unusual or unnecessary data. This includes checking for outliers, incorrect entries, or unexpected values that do not align with the expected categories or data types. Additionally, we will identify columns that are irrelevant to our analysis and consider removing them, especially those with excessive missing values or no meaningful contribution. Special cases with a limited number of unique values will also be assessed to determine whether they should be corrected, imputed, or removed. This step ensures that the dataset remains clean, relevant, and focused on the key attributes for analysis.

# %%
def extract_unique_attributes(df, column_name, separator=';'):
    # Split each cell by the separator and flatten the list of lists
    all_attributes = df[column_name].dropna().apply(lambda x: x.split(separator))
    
    # Flatten the list of lists to a single list of attributes
    flattened_attributes = [attribute.strip() for sublist in all_attributes for attribute in sublist]
    
    # Get unique attributes
    unique_attributes = set(flattened_attributes)
    
    return unique_attributes

# Apply the function to each column of interest
columns_to_check = ['category','brand','style', 'colors', 'occasion', 'pattern', 'gender', 'fit', 'Type', 'lenghth']

# Print the unique attributes for each column
for col in columns_to_check:
    unique_attrs = extract_unique_attributes(df_filtered, col)
    print(f"Unique attributes in '{col}':")
    print(unique_attrs)
    print("\n")
# Out:
# Unique attributes in 'category':
# {'coat', 'sweatshirt', 'trousers_and_chinos', 'shirt', 'overclothes-sleeveless', 'skirt', 'sportswear', 'cardigan', 'polo-shirt', 'blouse', 'sweatpants', 'jacket', 'tunic', 'hoodie', 't-shirt', 'dress', 'blazer', 'slippers-shoe', 'leggings', 'jumpsuit', 'sweater', 'tank-top', 'jeans', 'tops', 'poncho'}
#
#
# Unique attributes in 'brand':
# {'Marc Cain', 'Bianca', 'Her.', 'GERRY WEBER', 'Julia June', 'Marie Méro', 'Tommy Hilfiger', 'GERRY WEBER CASUAL', 'RAPHAELA by BRAX', 'Geisha', 'Street One', 'Black Rose', 'Four Roses', 'Accent', 'Pepe Jeans', 'Milestone', 'Dame Blanche', 'Liu Jo', 'VERO MODA', 'LeComte', 'HOX Italia', 'Scotch & Soda', 'Sommermann', 'Due Amanti', 'Part Two', 'ONLY', 'Tom Tailor', 'Yoek', 'SCHIESSER', 'Rabe', 'EVOKED VILA', 'Kocca', 'Cambio', 'Heart Mind', 'March23', 'Rosemunde', 'Betty Barclay', 'Frapp', 'Mexx', 'Via Appia Due', 'King Louie', 'Superdry', 'FAM the label', 'Terre Bleue', 'Gigue', "Herzen's Angelegenheit", 'Liu Jo Denim', 'Creenstone', 'Lyle & Scott', 'JustEve', 'Xandres', 'Senso', 'Y.A.S', 'Caroline Biss', 'Xandres Gold', 'Doris Streich', 'GERRY WEBER EDITION', 'Verpass', 'Marc Cain Sports', 'Mayerline', 'Taifun', 'Liu Jo Sport', 'RAINKISS', 'Nenette', 'Smashed Lemon', 'Vera Mont', 'Hampton Bays', 'Second Female', 'TONI', 'SELECTED FEMME', 'ETERNA', 'Joseph Ribkoff', 'Liu Jo White Label', 'CKS', 'Nümph', 'MAC', 'ONLY Carmakoma', 'Guess', 'Fabienne Chapot', 'Marc Cain Pants', 'ESPRIT', 'BRAX', 'River Woods', 'Bloomings'}
#
#
# Unique attributes in 'style':
# {'punk', 'casual', 'business', 'bohemian', 'sophisticated', 'feminine', 'minimalism', 'modest'}
#
#
# Unique attributes in 'colors':
# {'blue', 'black', 'bordeaux', 'pastel', 'emerald-green', 'ecru', 'red', 'silver', 'khaki', 'canyon-rose', 'nan', 'gold', 'navy', 'gray', 'yellow', 'white', 'mustard', 'orange', 'purple', 'turquoise', 'lavander', 'brown', 'neon', 'green', 'mint', 'magenta', 'beige', 'pink', 'coral'}
#
#
# Unique attributes in 'occasion':
# {'casual', 'sport', 'winter', 'nightout', 'home-lounge', 'formal', 'beach', 'office', 'summer', 'semi-formal', 'dating'}
#
#
# Unique attributes in 'pattern':
# {'horizontal-stripes', 'camo', 'net', 'harlequin', 'fruits', 'geometric', 'windowpane', 'brocade', 'retro', 'floral', 'diagonal-stripes', 'leaf', 'quilted', 'checkerboard', 'shapes', "bird's-eye", 'dots', 'marled', 'abstract', 'vertical-stripes', 'graph-check', 'zebra', 'houndstooth', 'tartan', 'plain', 'gingham', 'glitter', 'bleached', 'glen-check', 'stripes', 'damask', 'paisley', 'varsity-striped', 'text-print', 'animals', 'ombre', 'brush-stroke', 'animal-print', 'chevron', 'natural'}
#
#
# Unique attributes in 'gender':
# {'male', 'female', 'unisex'}
#
#
# Unique attributes in 'fit':
# {'Oversized_Fit', 'Regular_Fit', 'Slim_Fit', 'Flared_Fit'}
#
#
# Unique attributes in 'Type':
# {'turtle-neck', 'polo', 'sweetheart-neck', 'hooded', 'high-neck', 'shoulder-off', 'bodycon', 'waistcoat', 'flutter-sleeve', 'blend-coat', 'leather-overclothes', 'round-v-neck', 'low-waist', 'crew-neck', 'chinos', 'grandad', 'flare-sleeve', 'vests', 'round-neck', 'notched-collar', 'everyday-overclothes', 'trenchcoat', 'square-neck', 'dolman-sleeve', 'puffer', 'high-waist', 'one-shoulder', 'mermaid', 'casual', 'pencil', 'straight-sleeve', 'classic-trousers', 'sleeveless', 'puff-sleeve', 'sport-shorts', 'boat-neck', 'mid-waist', 'straps', 'clogs_and_mules', 'shawl-collar', 'a-line', 'cutaway', 'denim-overclothes', 'everyday-sweatshirt', 'v-neck', 'cape'}
#
#
# Unique attributes in 'lenghth':
# {'3-4-long', 'cropped', '3-4-sleeve', 'thigh-length', 'bottoms-length-undefined', 'skirt-length-undefined', 'sleeveless', 'mini', 'short', 'long', 'short-sleeve', 'above-knee', 'maxi', 'long-sleeve', 'straps', 'midi', 'full-length'}

# %% [markdown]
# __________________
# When I reviewed the attributes of each column for the final analysis, I found that the category column contained an attribute called "No detection." I went back to the initial visualization and noticed that there were very few instances of this category. Since it was not significant to the dataset, I decided to remove it.
# _________________________________

# %% [markdown]
# ___
# As we can see, some columns contain multiple attributes, which can make it more challenging for our model to achieve high accuracy and make predictions effectively. Additionally, removing rows with missing values would significantly reduce the dataset size. To address this, I decided to create two versions of the dataset: one where missing values are imputed using the mode or replaced with "Unknown," and another where rows with missing values are removed entirely.
# ___

# %%
df_Imputation = df_filtered.copy()
df_Imputation['style'] = df_Imputation['style'].fillna(df_Imputation['style'].mode()[0])
df_Imputation['colors'] = df_Imputation['colors'].fillna(df_Imputation['colors'].mode()[0])
df_Imputation['gender'] = df_Imputation['gender'].fillna(df_Imputation['gender'].mode()[0])
df_Imputation['occasion'] = df_Imputation['occasion'].fillna(df_Imputation['occasion'].mode()[0])
df_Imputation['Type'] = df_Imputation['Type'].fillna(df_Imputation['Type'].mode()[0])
df_Imputation['lenghth'] = df_Imputation['lenghth'].fillna(df_Imputation['lenghth'].mode()[0])

# Impute missing values in 'fit' with 'Unknown' if it's a crucial column
df_Imputation['fit'] = df_Imputation['fit'].fillna('Unknown')
df_Imputation['pattern'] = df_Imputation['pattern'].fillna('Unknown')

print(df_Imputation.isnull().sum())
# Out:
# image_url_1    0
# category       0
# style          0
# colors         0
# gender         0
# pattern        0
# occasion       0
# barcode        0
# brand          0
# fit            0
# Type           0
# lenghth        0
# dtype: int64

# %% [markdown]
# ____
# Imputing missing values using the mode or a placeholder like "Unknown" can simplify the dataset but introduces certain risks. It may reduce data variability, introduce bias, and potentially impact model performance by overrepresenting certain categories. Additionally, it can mask the underlying reasons for missing data, leading to inaccurate conclusions. To mitigate these risks, it's crucial to carefully analyze the missingness pattern, consider alternative imputation methods, and monitor the impact on model accuracy to ensure the integrity of the dataset is maintained.
# ____

# %%
df_Drop = df_filtered.copy()
df_Drop = df_Drop.dropna(subset=['fit'])
df_Drop = df_Drop.dropna(subset=['pattern'])
df_Drop = df_Drop.dropna(subset=['style'])

print(df_Drop.isnull().sum())
# Out:
# image_url_1    0
# category       0
# style          0
# colors         0
# gender         0
# pattern        0
# occasion       0
# barcode        0
# brand          0
# fit            0
# Type           0
# lenghth        0
# dtype: int64

# %%
df_Imputation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image_url_1  477 non-null    object
#  1   category     477 non-null    object
#  2   style        477 non-null    object
#  3   colors       477 non-null    object
#  4   gender       477 non-null    object
#  5   pattern      477 non-null    object
#  6   occasion     477 non-null    object
#  7   barcode      477 non-null    int64
#  8   brand        477 non-null    object
#  9   fit          477 non-null    object
#  10  Type         477 non-null    object
#  11  lenghth      477 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 48.4+ KB

# %%
df_Drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image_url_1  296 non-null    object
#  1   category     296 non-null    object
#  2   style        296 non-null    object
#  3   colors       296 non-null    object
#  4   gender       296 non-null    object
#  5   pattern      296 non-null    object
#  6   occasion     296 non-null    object
#  7   barcode      296 non-null    int64
#  8   brand        296 non-null    object
#  9   fit          296 non-null    object
#  10  Type         296 non-null    object
#  11  lenghth      296 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 30.1+ KB

# %%
df_Imputation.to_csv("data/dataset_imputed.csv", index=False)
df_Drop.to_csv("data/dataset_droped.csv", index=False)

# %%
def plot_multivalued_columns(df, column_names, separator=";"):
    """
    Function to plot the distribution of multiple columns containing multiple attributes per row.

    Parameters:
    df (DataFrame): The dataset.
    column_names (list): List of column names to visualize.
    separator (str): The separator used to split multiple attributes (default is ";").
    """
    num_columns = len(column_names)
    if num_columns == 0:
        print("No valid columns provided.")
        return
    
    fig, axes = plt.subplots(nrows=(num_columns + 1) // 2, ncols=2, figsize=(15, 5 * ((num_columns + 1) // 2)))
    axes = axes.flatten() if num_columns > 1 else [axes]
    
    for i, column_name in enumerate(column_names):
        if column_name not in df.columns:
            print(f"Column '{column_name}' not found in the dataset.")
            continue
        
        # Process the column
        df_expanded = df[column_name].dropna().astype(str).str.split(separator).explode().str.strip()
        attribute_counts = df_expanded.value_counts()
        
        sns.barplot(y=attribute_counts.index, x=attribute_counts.values, hue=attribute_counts.index, palette="coolwarm", legend=False, ax=axes[i])
        axes[i].set_title(f"Distribution of Attributes in {column_name}")
        axes[i].set_xlabel("Count")
        axes[i].set_ylabel("Attributes")
    
    plt.tight_layout()
    plt.show()

# %%
selected_columns = [col for col in df_Imputation.columns if col not in ['brand', 'image_url_1', 'barcode']]
plot_multivalued_columns(df_Imputation,selected_columns)

# %%
selected_columns2 = [col for col in df_Imputation.columns if col not in ['brand', 'image_url_1', 'barcode']]
plot_multivalued_columns(df_Drop,selected_columns)

# %%
def count_attributes_frequency(df, separator=";"):
    """
    Function to count the total number of attributes in each column and the frequency of each unique attribute.

    Parameters:
    df (DataFrame): The dataset.
    separator (str): The separator used to split multiple attributes (default is ";").

    Returns:
    dict: A dictionary where keys are column names and values are DataFrames showing attribute counts.
    """
    attribute_counts = {}
    selected_columns = [col for col in df.columns if col not in ['brand', 'image_url_1', 'barcode']]

    for column in selected_columns:
        # Drop NaN values, convert to string, and split attributes
        df_expanded = (
            df[column].dropna().astype(str)
            .str.split(separator)
            .explode()
            .str.strip()
        )
        
        # Get value counts
        attribute_count_df = df_expanded.value_counts().reset_index()
        attribute_count_df.columns = [column, "Frequency"]
        
        # Store in dictionary
        attribute_counts[column] = attribute_count_df

        # Print total attributes in column
        total_attributes = df_expanded.count()
        print(f"Column: {column} - Total Attributes: {total_attributes}\n")
        print(attribute_count_df.head(10))  # Display top 10 attributes for each column
        print("-" * 50)

    return attribute_counts

# %%
count_attributes_frequency(df_Imputation)
# Out:
# Column: category - Total Attributes: 477
#
#               category  Frequency
# 0  trousers_and_chinos         90
# 1                dress         73
# 2                skirt         48
# 3              t-shirt         42
# 4               blouse         34
# 5              sweater         28
# 6           sweatshirt         23
# 7                jeans         22
# 8                shirt         20
# 9             cardigan         19
# --------------------------------------------------
# Column: style - Total Attributes: 477
#
#            style  Frequency
# 0         casual        354
# 1       feminine         87
# 2       business         20
# 3       bohemian          6
# 4         modest          5
# 5     minimalism          2
# 6  sophisticated          2
# 7           punk          1
# --------------------------------------------------
# Column: colors - Total Attributes: 663
#
#    colors  Frequency
# 0   black         65
# 1   white         62
# 2    ecru         58
# 3    navy         50
# 4    blue         46
# 5    gray         46
# 6   beige         43
# 7   green         33
# 8   brown         23
# 9  orange         22
# --------------------------------------------------
# Column: gender - Total Attributes: 477
#
#    gender  Frequency
# 0  female        370
# 1    male         56
# 2  unisex         51
# --------------------------------------------------
# Column: pattern - Total Attributes: 585
#
#               pattern  Frequency
# 0               plain        137
# 1             Unknown         72
# 2                leaf         41
# 3    vertical-stripes         37
# 4              floral         37
# 5              marled         23
# 6              shapes         18
# 7  horizontal-stripes         17
# 8             stripes         16
# 9             animals         15
# --------------------------------------------------
# Column: occasion - Total Attributes: 819
#
#       occasion  Frequency
# 0       casual        342
# 1       dating        125
# 2  semi-formal        100
# 3     nightout         62
# 4       summer         55
# 5       winter         50
# 6  home-lounge         41
# 7       office         24
# 8       formal         11
# 9        sport          5
# --------------------------------------------------
# Column: fit - Total Attributes: 479
#
#              fit  Frequency
# 0    Regular_Fit        189
# 1        Unknown        125
# 2  Oversized_Fit         84
# 3       Slim_Fit         74
# 4     Flared_Fit          7
# --------------------------------------------------
# Column: Type - Total Attributes: 938
#
#                Type  Frequency
# 0   straight-sleeve        185
# 1        high-waist        103
# 2            a-line         96
# 3            v-neck         89
# 4  classic-trousers         79
# 5         mid-waist         58
# 6         crew-neck         44
# 7        round-neck         39
# 8         high-neck         24
# 9       puff-sleeve         23
# --------------------------------------------------
# Column: lenghth - Total Attributes: 729
#
#         lenghth  Frequency
# 0         short        146
# 1   long-sleeve        143
# 2   full-length         92
# 3          midi         85
# 4  short-sleeve         50
# 5  thigh-length         47
# 6    3-4-sleeve         46
# 7       cropped         38
# 8          mini         24
# 9      3-4-long         23
# --------------------------------------------------
# {'category':                   category  Frequency
#  0      trousers_and_chinos         90
#  1                    dress         73
#  2                    skirt         48
#  3                  t-shirt         42
#  4                   blouse         34
#  5                  sweater         28
#  6               sweatshirt         23
#  7                    jeans         22
#  8                    shirt         20
#  9                 cardigan         19
#  10                    tops         16
#  11                  jacket         10
#  12                tank-top         10
#  13              polo-shirt          8
#  14                  blazer          7
#  15  overclothes-sleeveless          5
#  16                  hoodie          5
#  17                jumpsuit          4
#  18                    coat          4
#  19                   tunic          3
#  20              sweatpants          2
#  21           slippers-shoe          1
#  22                leggings          1
#  23              sportswear          1
#  24                  poncho          1,
#  'style':            style  Frequency
#  0         casual        354
#  1       feminine         87
#  2       business         20
#  3       bohemian          6
#  4         modest          5
#  5     minimalism          2
#  6  sophisticated          2
#  7           punk          1,
#  'colors':            colors  Frequency
#  0           black         65
#  1           white         62
#  2            ecru         58
#  3            navy         50
#  4            blue         46
#  5            gray         46
#  6           beige         43
#  7           green         33
#  8           brown         23
#  9          orange         22
#  10         yellow         18
#  11        mustard         18
#  12          coral         17
#  13            nan         17
#  14         purple         17
#  15       lavander         17
#  16        magenta         13
#  17          khaki         13
#  18           pink         13
#  19            red         11
#  20  emerald-green         11
#  21         pastel          9
#  22       bordeaux          8
#  23           gold          8
#  24         silver          8
#  25      turquoise          6
#  26    canyon-rose          5
#  27           mint          4
#  28           neon          2,
#  'gender':    gender  Frequency
#  0  female        370
#  1    male         56
#  2  unisex         51,
#  'pattern':                pattern  Frequency
#  0                plain        137
#  1              Unknown         72
#  2                 leaf         41
#  3     vertical-stripes         37
#  4               floral         37
#  5               marled         23
#  6               shapes         18
#  7   horizontal-stripes         17
#  8              stripes         16
#  9              animals         15
#  10            bleached         15
#  11            abstract         14
#  12          text-print         14
#  13             chevron         13
#  14           geometric         12
#  15        animal-print          9
#  16             quilted          9
#  17             natural          8
#  18              fruits          7
#  19        brush-stroke          6
#  20     varsity-striped          5
#  21          bird's-eye          5
#  22               zebra          5
#  23             paisley          5
#  24          glen-check          5
#  25                dots          5
#  26          windowpane          5
#  27              tartan          4
#  28             glitter          4
#  29         graph-check          3
#  30         houndstooth          3
#  31           harlequin          2
#  32    diagonal-stripes          2
#  33                 net          2
#  34               retro          2
#  35             brocade          2
#  36             gingham          2
#  37        checkerboard          1
#  38                camo          1
#  39               ombre          1
#  40              damask          1,
#  'occasion':        occasion  Frequency
#  0        casual        342
#  1        dating        125
#  2   semi-formal        100
#  3      nightout         62
#  4        summer         55
#  5        winter         50
#  6   home-lounge         41
#  7        office         24
#  8        formal         11
#  9         sport          5
#  10        beach          4,
#  'fit':              fit  Frequency
#  0    Regular_Fit        189
#  1        Unknown        125
#  2  Oversized_Fit         84
#  3       Slim_Fit         74
#  4     Flared_Fit          7,
#  'Type':                     Type  Frequency
#  0        straight-sleeve        185
#  1             high-waist        103
#  2                 a-line         96
#  3                 v-neck         89
#  4       classic-trousers         79
#  5              mid-waist         58
#  6              crew-neck         44
#  7             round-neck         39
#  8              high-neck         24
#  9            puff-sleeve         23
#  10             boat-neck         21
#  11                pencil         20
#  12         dolman-sleeve         18
#  13          round-v-neck         16
#  14                  polo         15
#  15                chinos          9
#  16        flutter-sleeve          9
#  17            sleeveless          9
#  18                hooded          8
#  19               cutaway          8
#  20        notched-collar          7
#  21           turtle-neck          6
#  22   everyday-sweatshirt          5
#  23                 vests          4
#  24          flare-sleeve          4
#  25          shawl-collar          4
#  26  everyday-overclothes          4
#  27             low-waist          3
#  28     denim-overclothes          3
#  29               bodycon          3
#  30                casual          2
#  31            blend-coat          2
#  32           square-neck          2
#  33               mermaid          2
#  34                puffer          2
#  35   leather-overclothes          2
#  36               grandad          1
#  37          shoulder-off          1
#  38                straps          1
#  39       sweetheart-neck          1
#  40             waistcoat          1
#  41       clogs_and_mules          1
#  42          one-shoulder          1
#  43                  cape          1
#  44            trenchcoat          1
#  45          sport-shorts          1,
#  'lenghth':                      lenghth  Frequency
#  0                      short        146
#  1                long-sleeve        143
#  2                full-length         92
#  3                       midi         85
#  4               short-sleeve         50
#  5               thigh-length         47
#  6                 3-4-sleeve         46
#  7                    cropped         38
#  8                       mini         24
#  9                   3-4-long         23
#  10                sleeveless         13
#  11                      maxi          8
#  12  bottoms-length-undefined          5
#  13    skirt-length-undefined          4
#  14                      long          3
#  15                    straps          1
#  16                above-knee          1}

# %%
count_attributes_frequency(df_Drop)
# Out:
# Column: category - Total Attributes: 296
#
#               category  Frequency
# 0  trousers_and_chinos         74
# 1              t-shirt         37
# 2               blouse         29
# 3              sweater         27
# 4                jeans         20
# 5           sweatshirt         19
# 6                shirt         16
# 7             cardigan         14
# 8                 tops         12
# 9             tank-top         10
# --------------------------------------------------
# Column: style - Total Attributes: 296
#
#       style  Frequency
# 0    casual        256
# 1  business         18
# 2  feminine         15
# 3    modest          3
# 4  bohemian          3
# 5      punk          1
# --------------------------------------------------
# Column: colors - Total Attributes: 396
#
#    colors  Frequency
# 0    ecru         43
# 1   white         37
# 2   black         36
# 3    blue         33
# 4    gray         31
# 5    navy         31
# 6   beige         30
# 7   green         21
# 8   brown         13
# 9  orange         11
# --------------------------------------------------
# Column: gender - Total Attributes: 296
#
#    gender  Frequency
# 0  female        224
# 1    male         36
# 2  unisex         36
# --------------------------------------------------
# Column: pattern - Total Attributes: 366
#
#               pattern  Frequency
# 0               plain        106
# 1    vertical-stripes         29
# 2              marled         21
# 3              shapes         16
# 4  horizontal-stripes         15
# 5                leaf         15
# 6          text-print         14
# 7            bleached         14
# 8             animals         13
# 9              floral         11
# --------------------------------------------------
# Column: occasion - Total Attributes: 486
#
#       occasion  Frequency
# 0       casual        231
# 1  semi-formal         61
# 2       winter         39
# 3       dating         37
# 4     nightout         34
# 5  home-lounge         32
# 6       summer         21
# 7       office         19
# 8       formal          8
# 9        sport          4
# --------------------------------------------------
# Column: fit - Total Attributes: 298
#
#              fit  Frequency
# 0    Regular_Fit        161
# 1  Oversized_Fit         70
# 2       Slim_Fit         63
# 3     Flared_Fit          4
# --------------------------------------------------
# Column: Type - Total Attributes: 535
#
#                Type  Frequency
# 0   straight-sleeve        118
# 1  classic-trousers         65
# 2         mid-waist         47
# 3        high-waist         47
# 4         crew-neck         41
# 5            v-neck         33
# 6        round-neck         26
# 7         boat-neck         17
# 8         high-neck         16
# 9     dolman-sleeve         14
# --------------------------------------------------
# Column: lenghth - Total Attributes: 444
#
#                     lenghth  Frequency
# 0                     short        122
# 1               long-sleeve        111
# 2               full-length         75
# 3              thigh-length         39
# 4                   cropped         33
# 5              short-sleeve         22
# 6                  3-4-long         18
# 7                3-4-sleeve         15
# 8  bottoms-length-undefined          5
# 9                      long          3
# --------------------------------------------------
# {'category':                   category  Frequency
#  0      trousers_and_chinos         74
#  1                  t-shirt         37
#  2                   blouse         29
#  3                  sweater         27
#  4                    jeans         20
#  5               sweatshirt         19
#  6                    shirt         16
#  7                 cardigan         14
#  8                     tops         12
#  9                 tank-top         10
#  10                  jacket         10
#  11                  blazer          5
#  12                    coat          4
#  13                  hoodie          4
#  14              polo-shirt          4
#  15  overclothes-sleeveless          4
#  16                   tunic          3
#  17                jumpsuit          3
#  18              sweatpants          1,
#  'style':       style  Frequency
#  0    casual        256
#  1  business         18
#  2  feminine         15
#  3    modest          3
#  4  bohemian          3
#  5      punk          1,
#  'colors':            colors  Frequency
#  0            ecru         43
#  1           white         37
#  2           black         36
#  3            blue         33
#  4            gray         31
#  5            navy         31
#  6           beige         30
#  7           green         21
#  8           brown         13
#  9          orange         11
#  10       lavander         10
#  11          coral         10
#  12          khaki         10
#  13            nan         10
#  14        mustard          8
#  15         pastel          7
#  16        magenta          7
#  17         purple          7
#  18         yellow          7
#  19           pink          6
#  20  emerald-green          6
#  21       bordeaux          5
#  22            red          5
#  23         silver          4
#  24      turquoise          3
#  25    canyon-rose          2
#  26           mint          1
#  27           neon          1
#  28           gold          1,
#  'gender':    gender  Frequency
#  0  female        224
#  1    male         36
#  2  unisex         36,
#  'pattern':                pattern  Frequency
#  0                plain        106
#  1     vertical-stripes         29
#  2               marled         21
#  3               shapes         16
#  4   horizontal-stripes         15
#  5                 leaf         15
#  6           text-print         14
#  7             bleached         14
#  8              animals         13
#  9               floral         11
#  10             stripes          9
#  11             chevron          9
#  12           geometric          9
#  13             quilted          9
#  14        animal-print          7
#  15            abstract          7
#  16          windowpane          5
#  17          bird's-eye          5
#  18              fruits          5
#  19     varsity-striped          5
#  20             natural          5
#  21               zebra          4
#  22             glitter          4
#  23              tartan          4
#  24         houndstooth          3
#  25        brush-stroke          3
#  26                dots          3
#  27          glen-check          3
#  28           harlequin          2
#  29                 net          2
#  30             gingham          2
#  31         graph-check          2
#  32        checkerboard          1
#  33                camo          1
#  34               retro          1
#  35               ombre          1
#  36             paisley          1,
#  'occasion':       occasion  Frequency
#  0       casual        231
#  1  semi-formal         61
#  2       winter         39
#  3       dating         37
#  4     nightout         34
#  5  home-lounge         32
#  6       summer         21
#  7       office         19
#  8       formal          8
#  9        sport          4,
#  'fit':              fit  Frequency
#  0    Regular_Fit        161
#  1  Oversized_Fit         70
#  2       Slim_Fit         63
#  3     Flared_Fit          4,
#  'Type':                     Type  Frequency
#  0        straight-sleeve        118
#  1       classic-trousers         65
#  2              mid-waist         47
#  3             high-waist         47
#  4              crew-neck         41
#  5                 v-neck         33
#  6             round-neck         26
#  7              boat-neck         17
#  8              high-neck         16
#  9          dolman-sleeve         14
#  10                  polo         10
#  11            sleeveless          9
#  12           puff-sleeve          9
#  13                chinos          9
#  14          round-v-neck          8
#  15                hooded          8
#  16               cutaway          7
#  17           turtle-neck          6
#  18        notched-collar          5
#  19   everyday-sweatshirt          5
#  20  everyday-overclothes          4
#  21          shawl-collar          4
#  22        flutter-sleeve          4
#  23     denim-overclothes          3
#  24                 vests          3
#  25          flare-sleeve          3
#  26            blend-coat          2
#  27   leather-overclothes          2
#  28           square-neck          2
#  29                puffer          2
#  30       sweetheart-neck          1
#  31                straps          1
#  32             waistcoat          1
#  33            trenchcoat          1
#  34          one-shoulder          1
#  35             low-waist          1,
#  'lenghth':                      lenghth  Frequency
#  0                      short        122
#  1                long-sleeve        111
#  2                full-length         75
#  3               thigh-length         39
#  4                    cropped         33
#  5               short-sleeve         22
#  6                   3-4-long         18
#  7                 3-4-sleeve         15
#  8   bottoms-length-undefined          5
#  9                       long          3
#  10                sleeveless          1}

# %% [markdown]
# Some attributes have low frequency, which might require removal. However, I will keep them for now, as we may be able to group them with other attributes later. To do this effectively, we might need input from an expert.
